# %% [markdown]
# # **Análisis Exploratorio (EDA)**
#
# Utilizar visualizaciones para descubrir patrones, distribuciones y relaciones entre las variables.

# %% [markdown]
# # 1.- **Importar librerias**

# %%
# Importar librerías estándar
import sys
import os

# 2. Configurar la ruta para que Python encuentre el código en 'src'. Esto añade la carpeta raíz del proyecto al sys.path
ruta_raiz_proyecto = os.path.abspath(os.path.join(os.getcwd(), '../../'))
sys.path.append(ruta_raiz_proyecto)

# 3. Importar las funciones directamente.
from src.cargar_analisis import cargar_dataframe, crear_listas_variables
from src.eda import analisis_exploratorio_numerico, analisis_exploratorio_categorico, analisis_variable_objetivo

print("Funciones importadas exitosamente desde src/")
# Out:
# Funciones importadas exitosamente desde src/

# %% [markdown]
# # **2.- Importar datos**

# %%
# Ruta de la base de datos
path_data = '../../data/obesity_estimation_cleaned.csv'

# Ejecutar función para cargar datos
df = cargar_dataframe(path_data)

# Ejecutar la función para generar listas con las variables numericas, categoricas y objetivo
variables_numericas, variables_categoricas, variable_objetivo = crear_listas_variables(to_lower = 1, exclude_mixed = 1)
# Out:
# Archivo CSV cargado exitosamente desde: ../../data/obesity_estimation_cleaned.csv

# %% [markdown]
# # **3.- Análisis Exploratorio (EDA)**

# %% [markdown]
# ## 3.1.- Variables númericas

# %%
analisis_exploratorio_numerico(df, variables_numericas, variable_objetivo)
# Out:
# ---
# ## **Análisis Exploratorio de Variables Numéricas**
# ---
# ### 1. Resumen Estadístico
#          count       mean        std        min        25%        50%  \
# age     1946.0  24.148324   5.938280  15.000000  19.983146  22.851804
# height  1946.0   1.704715   0.092479   1.456346   1.634428   1.704180
# weight  1946.0  86.897181  25.951658  39.101805  66.031741  83.544074
# fcvc    1946.0   2.420032   0.528187   1.000000   2.000000   2.408561
# ncp     1946.0   2.691787   0.766672   1.000000   2.696268   3.000000
# ch2o    1946.0   2.016276   0.604417   1.000000   1.622270   2.000000
# faf     1946.0   1.021618   0.844441   0.000000   0.159962   1.000000
# tue     1946.0   0.672193   0.604946   0.000000   0.001754   0.632467
#
#                75%         max  skewness  kurtosis
# age      26.000000   47.706100  1.280630  1.267018
# height    1.770093    1.980000 -0.044709 -0.512069
# weight  108.017559  165.057269  0.215544 -0.742292
# fcvc      3.000000    3.000000 -0.428384 -0.628485
# ncp       3.000000    4.000000 -1.136867  0.478322
# ch2o      2.479917    3.000000 -0.119871 -0.830984
# faf       1.663930    3.000000  0.479091 -0.618850
# tue       1.000000    2.000000  0.596416 -0.543372
# ### 2. Distribución de Cada Variable Numérica
# ### 3. Mapa de Calor de Correlación
# ### 4. Relación de Variables Numéricas con 'nobeyesdad'
# #### **Media de cada variable por categoría de obesidad**
#               age  height  weight  fcvc   ncp  ch2o   faf   tue
# nobeyesdad
# 0           19.80    1.69   50.07  2.49  2.92  1.89  1.28  0.85
# 1           21.57    1.68   62.92  2.33  2.74  1.85  1.30  0.70
# 2           23.31    1.69   74.56  2.28  2.52  2.06  1.06  0.61
# 3           26.43    1.71   82.41  2.26  2.50  2.03  0.96  0.73
# 4           25.54    1.70   93.50  2.18  2.45  2.13  1.00  0.72
# 5           28.13    1.77  115.03  2.39  2.75  1.88  0.95  0.52
# 6           23.52    1.69  119.96  2.99  3.00  2.22  0.67  0.60
# #### **Distribución de cada variable por categoría de obesidad**

# %% [markdown]
# ## 3.2.- Variables categóricas

# %%
analisis_exploratorio_categorico(df, variables_categoricas, variable_objetivo)
# Out:
# ---
# ## **Análisis Exploratorio de Variables Categóricas**
# ---
# ### 1. Resumen Estadístico
#                                count unique                    top  freq
# gender                          1946      2                   male  1013
# family_history_with_overweight  1946      2                    yes  1608
# favc                            1946      2                    yes  1727
# caec                            1946      4              sometimes  1640
# smoke                           1946      2                     no  1908
# scc                             1946      2                     no  1860
# calc                            1946      4              sometimes  1318
# mtrans                          1946      5  public_transportation  1461
# ### 2. Distribución de Cada Variable Categórica
# ### 3. Relación con la Variable Objetivo: 'nobeyesdad'
# ### 4. Prueba de Asociación Estadística (Chi-Cuadrado)
#                          Variable  Chi2 Statistic        P-Value  \
# 3                            caec      708.253770  1.005294e-138
# 0                          gender      611.556131  7.497160e-129
# 1  family_history_with_overweight      556.735217  4.986678e-117
# 6                            calc      301.554959   2.305965e-53
# 7                          mtrans      275.956879   1.120167e-44
# 2                            favc      208.721686   2.636509e-42
# 5                             scc      117.208055   6.284021e-23
# 4                           smoke       29.297034   5.344613e-05
#
#    Asociación Significativa (p < 0.05)
# 3                                 True
# 0                                 True
# 1                                 True
# 6                                 True
# 7                                 True
# 2                                 True
# 5                                 True
# 4                                 True

# %% [markdown]
# ## 3.3.- Variable Objetivo

# %%
analisis_variable_objetivo(df, variable_objetivo, variables_numericas, variables_categoricas)
# Out:
# ---
# ## **Análisis de la Variable Objetivo: 'nobeyesdad'**
# ---
# ### 1. Distribución de las Clases
# ### 2. Perfil Categórico Más Común (Moda) por Categoría
# Esta tabla muestra el hábito o característica más frecuente para cada nivel de obesidad.
#             gender family_history_with_overweight favc       caec smoke scc  \
# nobeyesdad
# 0           female                             no  yes  sometimes    no  no
# 1             male                            yes  yes  sometimes    no  no
# 2             male                            yes  yes  sometimes    no  no
# 3             male                            yes  yes  sometimes    no  no
# 4             male                            yes  yes  sometimes    no  no
# 5             male                            yes  yes  sometimes    no  no
# 6           female                            yes  yes  sometimes    no  no
#
#                  calc                 mtrans
# nobeyesdad
# 0           sometimes  public_transportation
# 1           sometimes  public_transportation
# 2           sometimes  public_transportation
# 3           sometimes  public_transportation
# 4           sometimes  public_transportation
# 5           sometimes  public_transportation
# 6           sometimes  public_transportation
